# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('base.csv', encoding='ISO-8859-1')

# %%
#Total registros
tot_reg=len(data)
tot_reg
# Out:
# 3000

# %%
tot_colum=len(data.columns)
tot_colum
# Out:
# 9

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        3000 non-null   int64
#  1   Edad                      3000 non-null   int64
#  2   Genero                    3000 non-null   object
#  3   Ingresos Anuales          3000 non-null   int64
#  4   Gasto Mensual             3000 non-null   int64
#  5   Puntuación de Crédito     3000 non-null   int64
#  6   Región                    3000 non-null   object
#  7   Comportamiento en linea   3000 non-null   int64
#  8   Compras en el ultimo año  3000 non-null   int64
# dtypes: int64(7), object(2)
# memory usage: 211.1+ KB

# %%
#Identificar columnas categóricas y numéricas
columnas_categoricas= data.select_dtypes(include=['object'])
columnas_numericas= data.select_dtypes(include=['int64','float64'])

# %%
columnas_categoricas
# Out:
#          Genero Región
# 0     Masculino    Sur
# 1     Masculino  Oeste
# 2     Masculino  Oeste
# 3      Femenino    Sur
# 4      Femenino    Sur
# ...         ...    ...
# 2995  Masculino    Sur
# 2996  Masculino  Oeste
# 2997  Masculino   Este
# 2998   Femenino  Norte
# 2999   Femenino    Sur
#
# [3000 rows x 2 columns]

# %%
columnas_numericas
# Out:
#         ID  Edad  Ingresos Anuales  Gasto Mensual  Puntuación de Crédito  \
# 0        1    21            222011           2297                    335
# 1        2    26            239229           3420                    329
# 2        3    38            716278          36965                    711
# 3        4    64            697325           9846                    855
# 4        5    52           1032569           6607                    989
# ...    ...   ...               ...            ...                    ...
# 2995  2996    31           1724725          25756                    792
# 2996  2997    46           1683667          29508                    504
# 2997  2998    26            193267           5940                    421
# 2998  2999    21            106725           1762                    440
# 2999  3000    21            152149           5562                    405
#
#       Comportamiento en linea  Compras en el ultimo año
# ...

# %%
data.isnull().sum()
# Out:
# ID                          0
# Edad                        0
# Genero                      0
# Ingresos Anuales            0
# Gasto Mensual               0
# Puntuación de Crédito       0
# Región                      0
# Comportamiento en linea     0
# Compras en el ultimo año    0
# dtype: int64

# %%
data=data.dropna()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        3000 non-null   int64
#  1   Edad                      3000 non-null   int64
#  2   Genero                    3000 non-null   object
#  3   Ingresos Anuales          3000 non-null   int64
#  4   Gasto Mensual             3000 non-null   int64
#  5   Puntuación de Crédito     3000 non-null   int64
#  6   Región                    3000 non-null   object
#  7   Comportamiento en linea   3000 non-null   int64
#  8   Compras en el ultimo año  3000 non-null   int64
# dtypes: int64(7), object(2)
# memory usage: 211.1+ KB

# %%
data['Ingreso anual a mensual'] = data['Ingresos Anuales']/12

# %%
data
# Out:
#         ID  Edad     Genero  Ingresos Anuales  Gasto Mensual  \
# 0        1    21  Masculino            222011           2297
# 1        2    26  Masculino            239229           3420
# 2        3    38  Masculino            716278          36965
# 3        4    64   Femenino            697325           9846
# 4        5    52   Femenino           1032569           6607
# ...    ...   ...        ...               ...            ...
# 2995  2996    31  Masculino           1724725          25756
# 2996  2997    46  Masculino           1683667          29508
# 2997  2998    26  Masculino            193267           5940
# 2998  2999    21   Femenino            106725           1762
# 2999  3000    21   Femenino            152149           5562
#
#       Puntuación de Crédito Región  Comportamiento en linea  \
# 0                       335    Sur                        8
# 1                       329  Oeste                       10
# ...

# %%
#Detalles columnas
det_col=data.describe()
det_col
# Out:
#                 ID         Edad  Ingresos Anuales  Gasto Mensual  \
# count  3000.000000  3000.000000      3.000000e+03    3000.000000
# mean   1500.500000    43.137000      7.458787e+05   17036.542667
# std     866.169729    16.239339      5.394438e+05   12741.646988
# min       1.000000    18.000000      1.000170e+05    1012.000000
# 25%     750.750000    27.000000      2.324990e+05    4731.750000
# 50%    1500.500000    46.000000      7.170055e+05   16474.000000
# 75%    2250.250000    57.000000      1.109204e+06   26681.250000
# max    3000.000000    70.000000      1.998151e+06   44975.000000
#
#        Puntuación de Crédito  Comportamiento en linea  \
# count            3000.000000              3000.000000
# mean              641.390333                 6.303667
# std               222.962069                 3.272057
# min               300.000000                 1.000000
# 25%               435.000000                 3.000000
# ...

# %%
fig, axes= plt.subplots(figsize=(18,10))
axes.scatter(data["Ingreso anual a mensual"], data["Gasto Mensual"])
axes.set_xlabel("Ingreso anual a mensual")
axes.set_ylabel("Gasto Mensual")
plt.show()

# %%
fig, axes= plt.subplots(figsize=(18,10))
axes.scatter(data["Ingresos Anuales"], data["Edad"])
axes.set_xlabel("Edad")
axes.set_ylabel("Ingresos Anuales a mensual")
plt.show()

# %%
fig, axes= plt.subplots(figsize=(18,10))
axes.scatter(data["Ingreso anual a mensual"], data["Puntuación de Crédito"])
axes.set_xlabel("Ingreso anual a mensual")
axes.set_ylabel("Puntuación de Crédito")
plt.show()

# %%
fig, axes= plt.subplots(figsize=(18,10))
axes.scatter(data["Ingresos Anuales"], data["Compras en el ultimo año"])
axes.set_xlabel("Ingresos Anuales")
axes.set_ylabel("Compras en el ultimo año")
plt.show()

# %%
data.hist()
# Out:
# array([[<Axes: title={'center': 'ID'}>, <Axes: title={'center': 'Edad'}>,
#         <Axes: title={'center': 'Ingresos Anuales'}>],
#        [<Axes: title={'center': 'Gasto Mensual'}>,
#         <Axes: title={'center': 'Puntuación de Crédito'}>,
#         <Axes: title={'center': 'Comportamiento en linea'}>],
#        [<Axes: title={'center': 'Compras en el ultimo año'}>,
#         <Axes: title={'center': 'Ingreso anual a mensual'}>, <Axes: >]],
#       dtype=object)

# %%
data['Edad'].corr(data['Ingresos Anuales'])
# Out:
# 0.4385711078798078

# %%
data['Ingresos Anuales'].corr(data['Gasto Mensual'])
# Out:
# 0.7342748108669649

# %%
data['Ingresos Anuales'].corr(data['Puntuación de Crédito'])
# Out:
# 0.34694272149936434

# %%
correlation_matrix = columnas_numericas.corr()
plt.figure(figsize=(18,12))
sns.heatmap(correlation_matrix,annot=True,cmap='coolwarm',fmt=".2f")
plt.title("Mapa de Correlaciones")
plt.show()

# %%
#Ordenando los datos/Agrupaciones
rangos=[0,3,5,7,11]
nombrerango=["A", "B", "C","D"]
#Crear una nueva variable
data['Rango_Comportamiento']=pd.cut(data['Comportamiento en linea'],rangos,labels=nombrerango)

# %%
data
# Out:
#         ID  Edad     Genero  Ingresos Anuales  Gasto Mensual  \
# 0        1    21  Masculino            222011           2297
# 1        2    26  Masculino            239229           3420
# 2        3    38  Masculino            716278          36965
# 3        4    64   Femenino            697325           9846
# 4        5    52   Femenino           1032569           6607
# ...    ...   ...        ...               ...            ...
# 2995  2996    31  Masculino           1724725          25756
# 2996  2997    46  Masculino           1683667          29508
# 2997  2998    26  Masculino            193267           5940
# 2998  2999    21   Femenino            106725           1762
# 2999  3000    21   Femenino            152149           5562
#
#       Puntuación de Crédito Región  Comportamiento en linea  \
# 0                       335    Sur                        8
# 1                       329  Oeste                       10
# ...
